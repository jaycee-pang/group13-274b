# %% [markdown]
# # Visualize Cellular Automata Output Files
# Cell states can also be visualized by running `visualize_automata.py`, which turns the entire file into a .gif visualizing cell states across the entire time scope of the simulation.
#
# This notebook demonstrates how to use some of the functions defined in `visualize_automata.py` to look at specific frames of the simulation individually.

# %%
# import packages
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from visualize_automata import *

# %%
# load data from a automata output .txt file
file_path = "../../Bin/automata_output.txt"
cell_df, n_frames = get_cell_states(file_path)
# Out:
# loading file...
# /home/sli4037/chem_274a/group13-274b/Utils/Visualizers/visualize_automata.py:18: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   cell_df = pd.read_csv(input_file, skiprows=7, sep=", ")

# %%
# view automata state at a specific time
time = 1
create_image(cell_df, time, name="Cellular_Automata")
